# %%
import pandas as pd
import numpy as np
from datetime import datetime
from pydantic import BaseModel
from typing import Dict, List, Optional

# %% [markdown]
# #### Explicação

# %%
class User(BaseModel):
    id: int
    name: str = 'John Doe'
    signup_ts: Optional[datetime] = None
    friends: List[int] = []

# %%
external_data = {
    'id': 123,
    #'signup_ts': '2019-06-01 12:22',
    'friends': [1, '2', b'3'],
}

user = User(**external_data)

# %% [markdown]
# #### Como aplicar

# %%
dados = pd.read_table("../datasets/Potencial_Novos_Clientes.txt",
                      sep="\t",
                      header=0)
dados.head()
# Out:
#    COD_CARTAO  IDADE_CLIENTE  RENDA_MENSAL_CLIENTE  BEHAVIOUR_SCORE_CLIENTE  \
# 0      212394             22                  1500                       52
# 1      279177             29                  1800                       94
# 2      291430             36                  1500                       89
# 3      176612             43                  1500                       48
# 4      223092             28                 12090                       89
#
#    QTD_TRANSACOES_3M  QTD_ITENS_3M  VALOR_GASTO_3M  TICKET_MEDIO_3M  \
# 0                  2             4             802           401.00
# 1                  5             5            1384           276.80
# 2                  5             6            1610           322.00
# 3                  3             4             836           278.67
# 4                  4             5            1318           329.50
#
#    FLAG_ELETRONICOS_3M SATISFACAO_ULTIMA_COMPRA  VALOR_GASTO_PROX_12M
# 0                    0      01_Muito_Satisfeito                   226
# 1                    1                03_Neutro                  2786
# 2                    1            Nao_Respondeu                  3737
# 3                    0      01_Muito_Satisfeito                  1162
# 4                    0            Nao_Respondeu                  2699

# %%
# Variáveis explicativas quantitativas (deixar vazio [] caso não haja nenhuma)
lista_X_quanti = ['IDADE_CLIENTE',
                  'RENDA_MENSAL_CLIENTE',
                  'BEHAVIOUR_SCORE_CLIENTE',
                  'QTD_TRANSACOES_3M',
                  'QTD_ITENS_3M',
                  'VALOR_GASTO_3M',
                  'TICKET_MEDIO_3M']

# Variáveis explicativas qualitativas (deixar vazio [] caso não haja nenhuma)
lista_X_quali = ['FLAG_ELETRONICOS_3M',
                 'SATISFACAO_ULTIMA_COMPRA']

# %%
X = dados[lista_X_quanti + lista_X_quali]
#X['FLAG_ELETRONICOS_3M'] = X['FLAG_ELETRONICOS_3M'].to_string()

# %%
class TrainDataSchema(BaseModel):
    """
    Data Input schema
    """
    IDADE_CLIENTE: int
    RENDA_MENSAL_CLIENTE: float
    BEHAVIOUR_SCORE_CLIENTE: float
    QTD_TRANSACOES_3M: float
    QTD_ITENS_3M: float
    VALOR_GASTO_3M: float
    TICKET_MEDIO_3M: float
    FLAG_ELETRONICOS_3M: int
    SATISFACAO_ULTIMA_COMPRA: str

# %%
class MultipleDataSchema(BaseModel):
    inputs: List[TrainDataSchema]

# %%
MultipleDataSchema(
    inputs=X.replace({np.nan: None}).to_dict(orient="records")
)
# Out:
# MultipleDataSchema(inputs=[TrainDataSchema(IDADE_CLIENTE=22, RENDA_MENSAL_CLIENTE=1500.0, BEHAVIOUR_SCORE_CLIENTE=52.0, QTD_TRANSACOES_3M=2.0, QTD_ITENS_3M=4.0, VALOR_GASTO_3M=802.0, TICKET_MEDIO_3M=401.0, FLAG_ELETRONICOS_3M=0, SATISFACAO_ULTIMA_COMPRA='01_Muito_Satisfeito'), TrainDataSchema(IDADE_CLIENTE=29, RENDA_MENSAL_CLIENTE=1800.0, BEHAVIOUR_SCORE_CLIENTE=94.0, QTD_TRANSACOES_3M=5.0, QTD_ITENS_3M=5.0, VALOR_GASTO_3M=1384.0, TICKET_MEDIO_3M=276.8, FLAG_ELETRONICOS_3M=1, SATISFACAO_ULTIMA_COMPRA='03_Neutro'), TrainDataSchema(IDADE_CLIENTE=36, RENDA_MENSAL_CLIENTE=1500.0, BEHAVIOUR_SCORE_CLIENTE=89.0, QTD_TRANSACOES_3M=5.0, QTD_ITENS_3M=6.0, VALOR_GASTO_3M=1610.0, TICKET_MEDIO_3M=322.0, FLAG_ELETRONICOS_3M=1, SATISFACAO_ULTIMA_COMPRA='Nao_Respondeu'), TrainDataSchema(IDADE_CLIENTE=43, RENDA_MENSAL_CLIENTE=1500.0, BEHAVIOUR_SCORE_CLIENTE=48.0, QTD_TRANSACOES_3M=3.0, QTD_ITENS_3M=4.0, VALOR_GASTO_3M=836.0, TICKET_MEDIO_3M=278.67, FLAG_ELETRONICOS_3M=0, SATISFACAO_ULTIMA_COMPRA='01_Muito_Satisfeito'), TrainDataSchema(IDADE_CLIENTE=28, RENDA_MENSAL_CLIENTE=12090.0, BEHAVIOUR_SCORE_CLIENTE=89.0, QTD_TRANSACOES_3M=4.0, QTD_ITENS_3M=5.0, VALOR_GASTO_3M=1318.0, TICKET_MEDIO_3M=329.5, FLAG_ELETRONICOS_3M=0, SATISFACAO_ULTIMA_COMPRA='Nao_Respondeu'), TrainDataSchema(IDADE_CLIENTE=18, RENDA_MENSAL_CLIENTE=1500.0, BEHAVIOUR_SCORE_CLIENTE=55.0, QTD_TRANSACOES_3M=1.0, QTD_ITENS_3M=3.0, VALOR_GASTO_3M=192.0, TICKET_MEDIO_3M=192.0, FLAG_ELETRONICOS_3M=0, SATISFACAO_ULTIMA_COMPRA='02_Satisfeito'), TrainDataSchema(IDADE_CLIENTE=53, RENDA_MENSAL_CLIENTE=15330.0, BEHAVIOUR_SCORE_CLIENTE=89.0, QTD_TRANSACOES_3M=4.0, QTD_ITENS_3M=8.0, VALOR_GASTO_3M=1095.0, TICKET_MEDIO_3M=273.75, FLAG_ELETRONICOS_3M=0, SATISFACAO_ULTIMA_COMPRA='03_Neutro'), TrainDataSchema(IDADE_CLIENTE=57, RENDA_MENSAL_CLIENTE=1500.0, BEHAVIOUR_SCORE_CLIENTE=73.0, QTD_TRANSACOES_3M=3.0, QTD_ITENS_3M=8.0, VALOR_GASTO_3M=2105.0, TICKET_MEDIO_3M=701.67, FLAG_ELETRONICOS_3M=0, SATISFACAO_ULTIMA_COMPRA='03_Neutro'), TrainDataSchema(IDADE_CLIENTE=35, RENDA_MENSAL_CLIENTE=1500.0, BEHAVIOUR_SCORE_CLIENTE=60.0, QTD_TRANSACOES_3M=2.0, QTD_ITENS_3M=1.0, VALOR_GASTO_3M=640.0, TICKET_MEDIO_3M=320.0, FLAG_ELETRONICOS_3M=0, SATISFACAO_ULTIMA_COMPRA='02_Satisfeito'), TrainDataSchema(IDADE_CLIENTE=34, RENDA_MENSAL_CLIENTE=1500.0, BEHAVIOUR_SCORE_CLIENTE=88.0, QTD_TRANSACOES_3M=3.0, QTD_ITENS_3M=5.0, VALOR_GASTO_3M=1879.0, TICKET_MEDIO_3M=626.33, FLAG_ELETRONICOS_3M=0, SATISFACAO_ULTIMA_COMPRA='Nao_Respondeu'), TrainDataSchema(IDADE_CLIENTE=28, RENDA_MENSAL_CLIENTE=11775.0, BEHAVIOUR_SCORE_CLIENTE=82.0, QTD_TRANSACOES_3M=2.0, QTD_ITENS_3M=5.0, VALOR_GASTO_3M=473.0, TICKET_MEDIO_3M=236.5, FLAG_ELETRONICOS_3M=0, SATISFACAO_ULTIMA_COMPRA='Nao_Respondeu'), TrainDataSchema(IDADE_CLIENTE=62, RENDA_MENSAL_CLIENTE=22035.0, BEHAVIOUR_SCORE_CLIENTE=94.0, QTD_TRANSACOES_3M=7.0, QTD_ITENS_3M=9.0, VALOR_GASTO_3M=2196.0, TICKET_MEDIO_3M=313.71, FLAG_ELETRONICOS_3M=1, SATISFACAO_ULTIMA_COMPRA='Nao_Respondeu'), TrainDataSchema(IDADE_CLIENTE=44, RENDA_MENSAL_CLIENTE=15375.0, BEHAVIOUR_SCORE_CLIENTE=91.0, QTD_TRANSACOES_3M=4.0, QTD_ITENS_3M=7.0, VALOR_GASTO_3M=877.0, TICKET_MEDIO_3M=219.25, FLAG_ELETRONICOS_3M=1, SATISFACAO_ULTIMA_COMPRA='03_Neutro'), TrainDataSchema(IDADE_CLIENTE=57, RENDA_MENSAL_CLIENTE=20655.0, BEHAVIOUR_SCORE_CLIENTE=69.0, QTD_TRANSACOES_3M=2.0, QTD_ITENS_3M=7.0, VALOR_GASTO_3M=1203.0, TICKET_MEDIO_3M=601.5, FLAG_ELETRONICOS_3M=0, SATISFACAO_ULTIMA_COMPRA='02_Satisfeito'), TrainDataSchema(IDADE_CLIENTE=35, RENDA_MENSAL_CLIENTE=9540.0, BEHAVIOUR_SCORE_CLIENTE=74.0, QTD_TRANSACOES_3M=3.0, QTD_ITENS_3M=4.0, VALOR_GASTO_3M=1456.0, TICKET_MEDIO_3M=485.33, FLAG_ELETRONICOS_3M=0, SATISFACAO_ULTIMA_COMPRA='01_Muito_Satisfeito'), TrainDataSchema(IDADE_CLIENTE=40, RENDA_MENSAL_CLIENTE=16710.0, BEHAVIOUR_SCORE_CLIENTE=74.0, QTD_TRANSACOES_3M=2.0, QTD_ITENS_3M=6.0, VALOR_GASTO_3M=771.0, TICKET_MEDIO_3M=385.5, FLAG_ELETRONICOS_3M=0, SATISFACAO_ULTIMA_COMPRA='02_Satisfeito'), TrainDataSchema(IDADE_CLIENT ...
