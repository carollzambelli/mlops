# %% [markdown]
# Testando paths e validação dos dados

# %%
import pandas as pd
import numpy as np
from src.core import MultipleDataSchema, config, PACKAGE_ROOT

# %%
PACKAGE_ROOT
# Out:
# WindowsPath('C:/Users/Carolina/OneDrive/Github/mlops')

# %%
data = pd.read_csv(f'{PACKAGE_ROOT}/{config.ml_config.predict_data_path}', index_col=0)

# %%
data.head()
# Out:
#                id             date  bedrooms  bathrooms  sqft_living  \
# 17384  1453602313  20141029T000000         2       1.50         1430
# 722    2225059214  20140808T000000         4       3.25         4670
# 2680   2768000270  20140625T000000         2       0.75         1440
# 18754  6819100040  20140624T000000         2       1.00         1130
# 14554  4027700666  20150426T000000         4       2.50         3180
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 17384      1650     3.0           0     0          3      7        1430
# 722       51836     2.0           0     0          4     12        4670
# 2680       3700     1.0           0     0          3      7        1200
# 18754      2640     1.0           0     0          4      8        1130
# 14554      9603     2.0           0     2          3      9        3180
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
data = data[config.data_config.input_data_pred]

# %%
# valida os dados de entrada do modelo
MultipleDataSchema(
    inputs=data.replace({np.nan: None}).to_dict(orient="records")
)
# Out:
# MultipleDataSchema(inputs=[DataSchema(bedrooms=2, bathrooms=1.5, sqft_living=1430, sqft_lot=1650, floors=3.0, waterfront=0, view=0, condition=3, grade=7, sqft_above=1430, sqft_basement=0, yr_built=1999, yr_renovated=0, zipcode=98125, sqft_living15=1430, sqft_lot15=1650), DataSchema(bedrooms=4, bathrooms=3.25, sqft_living=4670, sqft_lot=51836, floors=2.0, waterfront=0, view=0, condition=4, grade=12, sqft_above=4670, sqft_basement=0, yr_built=1988, yr_renovated=0, zipcode=98005, sqft_living15=4230, sqft_lot15=41075), DataSchema(bedrooms=2, bathrooms=0.75, sqft_living=1440, sqft_lot=3700, floors=1.0, waterfront=0, view=0, condition=3, grade=7, sqft_above=1200, sqft_basement=240, yr_built=1914, yr_renovated=0, zipcode=98107, sqft_living15=1440, sqft_lot15=4300), DataSchema(bedrooms=2, bathrooms=1.0, sqft_living=1130, sqft_lot=2640, floors=1.0, waterfront=0, view=0, condition=4, grade=8, sqft_above=1130, sqft_basement=0, yr_built=1927, yr_renovated=0, zipcode=98109, sqft_living15=1680, sq
# ...

# %% [markdown]
# Testando a função de predição

# %%
from src.predict import make_prediction
from src.pipeline import df_model

# %%
df = df_model(data)
df.head()
# Out:
#        bedrooms  bathrooms  floors waterfront view condition  grade  yr_built  \
# 17384         2          1       3          0    0         3      7      1999
# 722           4          3       2          0    0         4  00000      1988
# 2680          2          0       1          0    0         3      7      1914
# 18754         2          1       1          0    0         4      8      1927
# 14554         4          2       2          0    2         3      9      2002
#
#        yr_renovated zipcode  ...  zipcode_encoded  view_encoded  \
# 17384             0   98125  ...              0.0           0.0
# 722               0   00000  ...              1.0           0.0
# 2680              0   00000  ...              1.0           0.0
# 18754             0   00000  ...              1.0           0.0
# 14554             0   98155  ...              2.0           1.0
#
#        condition_encoded  grade_encoded  sqft_living  sqft_lot  sqft_above  \
# ...

# %%
make_prediction()
# Out:
# INFO:root:Iniciado processo de aplicação do modelo
# INFO:root:modelo models\house_price_regression_2025-01-13.pkl carregado
# INFO:root:Dados validados
# INFO:root:4323 predições realizadas
# INFO:root:Predições salvas
# True
