# %%
import pandas as pd
import numpy as np
from src.core import MultipleDataSchema, config, PACKAGE_ROOT

# %%
PACKAGE_ROOT
# Out:
# WindowsPath('C:/Users/Carolina/OneDrive/Github/mlops')

# %%
data = pd.read_csv(f'{PACKAGE_ROOT}/{config.ml_config.predict_data_path}', index_col=0)

# %%
data.head()
# Out:
#                id             date  bedrooms  bathrooms  sqft_living  \
# 17384  1453602313  20141029T000000         2       1.50         1430
# 722    2225059214  20140808T000000         4       3.25         4670
# 2680   2768000270  20140625T000000         2       0.75         1440
# 18754  6819100040  20140624T000000         2       1.00         1130
# 14554  4027700666  20150426T000000         4       2.50         3180
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 17384      1650     3.0           0     0          3      7        1430
# 722       51836     2.0           0     0          4     12        4670
# 2680       3700     1.0           0     0          3      7        1200
# 18754      2640     1.0           0     0          4      8        1130
# 14554      9603     2.0           0     2          3      9        3180
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 17384              0      1999             0    98125  47.7222 -122.290
# 722                0      1988             0    98005  47.6350 -122.164
# 2680             240      1914             0    98107  47.6707 -122.364
# 18754              0      1927             0    98109  47.6438 -122.357
# 14554              0      2002             0    98155  47.7717 -122.277
#
#        sqft_living15  sqft_lot15
# 17384           1430        1650
# 722             4230       41075
# 2680            1440        4300
# 18754           1680        3200
# 14554           2440       15261

# %%
data[config.data_config.input_data_pred]
# Out:
# ['bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'sqft_living15',
#  'sqft_lot15']

# %%
inputs=data[config.data_config.input_data_pred].replace({np.nan: None}).to_dict(orient="records")
inputs
# Out:
# [{'bedrooms': 2,
#   'bathrooms': 1.5,
#   'sqft_living': 1430,
#   'sqft_lot': 1650,
#   'floors': 3.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1430,
#   'sqft_basement': 0,
#   'yr_built': 1999,
#   'yr_renovated': 0,
#   'zipcode': 98125,
#   'sqft_living15': 1430,
#   'sqft_lot15': 1650},
#  {'bedrooms': 4,
#   'bathrooms': 3.25,
#   'sqft_living': 4670,
#   'sqft_lot': 51836,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 12,
#   'sqft_above': 4670,
#   'sqft_basement': 0,
#   'yr_built': 1988,
#   'yr_renovated': 0,
#   'zipcode': 98005,
#   'sqft_living15': 4230,
#   'sqft_lot15': 41075},
#  {'bedrooms': 2,
#   'bathrooms': 0.75,
#   'sqft_living': 1440,
#   'sqft_lot': 3700,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1200,
#   'sqft_basement': 240,
#   'yr_built': 1914,
#   'yr_renovated': 0,
#   'zipcode': 98107,
#   'sqft_living15': 1440,
#   'sqft_lot15': 4300},
#  {'bedrooms': 2,
#   'bathrooms': 1.0,
#   'sqft_living': 1130,
#   'sqft_lot': 2640,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 8,
#   'sqft_above': 1130,
#   'sqft_basement': 0,
#   'yr_built': 1927,
#   'yr_renovated': 0,
#   'zipcode': 98109,
#   'sqft_living15': 1680,
#   'sqft_lot15': 3200},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 3180,
#   'sqft_lot': 9603,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 2,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 3180,
#   'sqft_basement': 0,
#   'yr_built': 2002,
#   'yr_renovated': 0,
#   'zipcode': 98155,
#   'sqft_living15': 2440,
#   'sqft_lot15': 15261},
#  {'bedrooms': 3,
#   'bathrooms': 2.5,
#   'sqft_living': 1650,
#   'sqft_lot': 3436,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1650,
#   'sqft_basement': 0,
#   'yr_built': 2003,
#   'yr_renovated': 0,
#   'zipcode': 98053,
#   'sqft_living15': 1680,
#   'sqft_lot15': 3446},
#  {'bedrooms': 3,
#   'bathrooms': 2.75,
#   'sqft_living': 1720,
#   'sqft_lot': 28000,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1720,
#   'sqft_basement': 0,
#   'yr_built': 1958,
#   'yr_renovated': 0,
#   'zipcode': 98058,
#   'sqft_living15': 2000,
#   'sqft_lot15': 41817},
#  {'bedrooms': 3,
#   'bathrooms': 2.5,
#   'sqft_living': 2538,
#   'sqft_lot': 4600,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 2538,
#   'sqft_basement': 0,
#   'yr_built': 2013,
#   'yr_renovated': 0,
#   'zipcode': 98092,
#   'sqft_living15': 2570,
#   'sqft_lot15': 4800},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2460,
#   'sqft_lot': 5440,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 2460,
#   'sqft_basement': 0,
#   'yr_built': 2003,
#   'yr_renovated': 0,
#   'zipcode': 98058,
#   'sqft_living15': 2460,
#   'sqft_lot15': 5124},
#  {'bedrooms': 5,
#   'bathrooms': 3.5,
#   'sqft_living': 4460,
#   'sqft_lot': 2975,
#   'floors': 3.0,
#   'waterfront': 0,
#   'view': 2,
#   'condition': 3,
#   'grade': 10,
#   'sqft_above': 3280,
#   'sqft_basement': 1180,
#   'yr_built': 2015,
#   'yr_renovated': 0,
#   'zipcode': 98119,
#   'sqft_living15': 2490,
#   'sqft_lot15': 4231},
#  {'bedrooms': 4,
#   'bathrooms': 1.75,
#   'sqft_living': 2360,
#   'sqft_lot': 11300,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 9,
#   'sqft_above': 2360,
#   'sqft_basement': 0,
#   'yr_built': 1974,
#   'yr_renovated': 0,
#   'zipcode': 98006,
#   'sqft_living15': 2290,
#   'sqft_lot15': 11951},
#  {'bedrooms': 3,
#   'bathrooms': 2.5,
#   'sqft_living': 1720,
#   'sqft_lot': 3581,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1720,
#   'sqft_basement': 0,
#   'yr_built': 2011,
#   'yr_renovated': 0,
#   'zipcode': 98053,
#   'sqft_living15': 1720,
#   'sqft_lot15': 3600},
#  {'bedrooms': 2,
#   'bathrooms': 1.5,
#   'sqft_living': 1020,
#   'sqft_lot': 1049,
#   'floors': 3.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 1020,
#   'sqft_basement': 0,
#   'yr_built': 2008,
#   'yr_renovated': 0,
#   'zipcode': 98103,
#   'sqft_living15': 1350,
#   'sqft_lot15': 1395},
#  {'bedrooms': 3,
#   'bathrooms': 1.5,
#   'sqft_living': 1340,
#   'sqft_lot': 11744,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 2,
#   'grade': 7,
#   'sqft_above': 1340,
#   'sqft_basement': 0,
#   'yr_built': 1950,
#   'yr_renovated': 0,
#   'zipcode': 98146,
#   'sqft_living15': 2020,
#   'sqft_lot15': 13673},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 3180,
#   'sqft_lot': 10105,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 9,
#   'sqft_above': 3180,
#   'sqft_basement': 0,
#   'yr_built': 1986,
#   'yr_renovated': 0,
#   'zipcode': 98040,
#   'sqft_living15': 2670,
#   'sqft_lot15': 10355},
#  {'bedrooms': 2,
#   'bathrooms': 1.75,
#   'sqft_living': 1220,
#   'sqft_lot': 2268,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 6,
#   'sqft_above': 610,
#   'sqft_basement': 610,
#   'yr_built': 1909,
#   'yr_renovated': 0,
#   'zipcode': 98144,
#   'sqft_living15': 1240,
#   'sqft_lot15': 1675},
#  {'bedrooms': 3,
#   'bathrooms': 2.25,
#   'sqft_living': 1530,
#   'sqft_lot': 3056,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1530,
#   'sqft_basement': 0,
#   'yr_built': 2003,
#   'yr_renovated': 0,
#   'zipcode': 98053,
#   'sqft_living15': 1560,
#   'sqft_lot15': 3064},
#  {'bedrooms': 4,
#   'bathrooms': 2.0,
#   'sqft_living': 2130,
#   'sqft_lot': 2620,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 5,
#   'grade': 7,
#   'sqft_above': 1650,
#   'sqft_basement': 480,
#   'yr_built': 1919,
#   'yr_renovated': 0,
#   'zipcode': 98103,
#   'sqft_living15': 1330,
#   'sqft_lot15': 2719},
#  {'bedrooms': 2,
#   'bathrooms': 1.0,
#   'sqft_living': 930,
#   'sqft_lot': 12724,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 6,
#   'sqft_above': 930,
#   'sqft_basement': 0,
#   'yr_built': 1912,
#   'yr_renovated': 0,
#   'zipcode': 98014,
#   'sqft_living15': 1240,
#   'sqft_lot15': 21828},
#  {'bedrooms': 3,
#   'bathrooms': 2.0,
#   'sqft_living': 1370,
#   'sqft_lot': 7200,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1130,
#   'sqft_basement': 240,
#   'yr_built': 1926,
#   'yr_renovated': 1955,
#   'zipcode': 98125,
#   'sqft_living15': 1300,
#   'sqft_lot15': 7208},
#  {'bedrooms': 3,
#   'bathrooms': 2.5,
#   'sqft_living': 1670,
#   'sqft_lot': 7740,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1130,
#   'sqft_basement': 540,
#   'yr_built': 1974,
#   'yr_renovated': 0,
#   'zipcode': 98126,
#   'sqft_living15': 1220,
#   'sqft_lot15': 7740},
#  {'bedrooms': 4,
#   'bathrooms': 2.75,
#   'sqft_living': 2220,
#   'sqft_lot': 8450,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1260,
#   'sqft_basement': 960,
#   'yr_built': 1983,
#   'yr_renovated': 0,
#   'zipcode': 98059,
#   'sqft_living15': 1580,
#   'sqft_lot15': 8450},
#  {'bedrooms': 4,
#   'bathrooms': 3.0,
#   'sqft_living': 1900,
#   'sqft_lot': 9077,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1900,
#   'sqft_basement': 0,
#   'yr_built': 1954,
#   'yr_renovated': 2015,
#   'zipcode': 98155,
#   'sqft_living15': 1900,
#   'sqft_lot15': 12868},
#  {'bedrooms': 3,
#   'bathrooms': 1.75,
#   'sqft_living': 1100,
#   'sqft_lot': 9452,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 6,
#   'sqft_above': 1100,
#   'sqft_basement': 0,
#   'yr_built': 1942,
#   'yr_renovated': 0,
#   'zipcode': 98146,
#   'sqft_living15': 1350,
#   'sqft_lot15': 9452},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2370,
#   'sqft_lot': 15200,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 1660,
#   'sqft_basement': 710,
#   'yr_built': 1975,
#   'yr_renovated': 0,
#   'zipcode': 98052,
#   'sqft_living15': 2360,
#   'sqft_lot15': 13879},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 1100,
#   'sqft_lot': 5132,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 6,
#   'sqft_above': 840,
#   'sqft_basement': 260,
#   'yr_built': 1948,
#   'yr_renovated': 0,
#   'zipcode': 98103,
#   'sqft_living15': 1280,
#   'sqft_lot15': 5132},
#  {'bedrooms': 4,
#   'bathrooms': 2.0,
#   'sqft_living': 1530,
#   'sqft_lot': 7816,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1530,
#   'sqft_basement': 0,
#   'yr_built': 1955,
#   'yr_renovated': 0,
#   'zipcode': 98133,
#   'sqft_living15': 1480,
#   'sqft_lot15': 7816},
#  {'bedrooms': 4,
#   'bathrooms': 1.75,
#   'sqft_living': 1640,
#   'sqft_lot': 7194,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1480,
#   'sqft_basement': 160,
#   'yr_built': 1915,
#   'yr_renovated': 0,
#   'zipcode': 98011,
#   'sqft_living15': 1440,
#   'sqft_lot15': 9405},
#  {'bedrooms': 2,
#   'bathrooms': 1.75,
#   'sqft_living': 2110,
#   'sqft_lot': 8700,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 4,
#   'condition': 4,
#   'grade': 9,
#   'sqft_above': 1760,
#   'sqft_basement': 350,
#   'yr_built': 1960,
#   'yr_renovated': 0,
#   'zipcode': 98146,
#   'sqft_living15': 2120,
#   'sqft_lot15': 9500},
#  {'bedrooms': 3,
#   'bathrooms': 1.5,
#   'sqft_living': 1690,
#   'sqft_lot': 6010,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1230,
#   'sqft_basement': 460,
#   'yr_built': 1946,
#   'yr_renovated': 0,
#   'zipcode': 98115,
#   'sqft_living15': 1690,
#   'sqft_lot15': 5418},
#  {'bedrooms': 2,
#   'bathrooms': 3.25,
#   'sqft_living': 2070,
#   'sqft_lot': 3128,
#   'floors': 2.0,
#   'waterfront': 1,
#   'view': 3,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 1760,
#   'sqft_basement': 310,
#   'yr_built': 1988,
#   'yr_renovated': 0,
#   'zipcode': 98075,
#   'sqft_living15': 2740,
#   'sqft_lot15': 3568},
#  {'bedrooms': 4,
#   'bathrooms': 1.75,
#   'sqft_living': 2020,
#   'sqft_lot': 6200,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 6,
#   'sqft_above': 1010,
#   'sqft_basement': 1010,
#   'yr_built': 1948,
#   'yr_renovated': 0,
#   'zipcode': 98133,
#   'sqft_living15': 1440,
#   'sqft_lot15': 4158},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2560,
#   'sqft_lot': 43560,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 2560,
#   'sqft_basement': 0,
#   'yr_built': 1989,
#   'yr_renovated': 0,
#   'zipcode': 98038,
#   'sqft_living15': 2130,
#   'sqft_lot15': 10150},
#  {'bedrooms': 4,
#   'bathrooms': 3.25,
#   'sqft_living': 3330,
#   'sqft_lot': 9000,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 2870,
#   'sqft_basement': 460,
#   'yr_built': 2004,
#   'yr_renovated': 0,
#   'zipcode': 98033,
#   'sqft_living15': 2550,
#   'sqft_lot15': 6349},
#  {'bedrooms': 4,
#   'bathrooms': 2.25,
#   'sqft_living': 3070,
#   'sqft_lot': 13720,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 3070,
#   'sqft_basement': 0,
#   'yr_built': 1978,
#   'yr_renovated': 0,
#   'zipcode': 98007,
#   'sqft_living15': 3010,
#   'sqft_lot15': 9657},
#  {'bedrooms': 3,
#   'bathrooms': 2.5,
#   'sqft_living': 1820,
#   'sqft_lot': 16300,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1220,
#   'sqft_basement': 600,
#   'yr_built': 1955,
#   'yr_renovated': 0,
#   'zipcode': 98166,
#   'sqft_living15': 1870,
#   'sqft_lot15': 16300},
#  {'bedrooms': 3,
#   'bathrooms': 1.5,
#   'sqft_living': 1260,
#   'sqft_lot': 1270,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1040,
#   'sqft_basement': 220,
#   'yr_built': 2005,
#   'yr_renovated': 0,
#   'zipcode': 98133,
#   'sqft_living15': 1260,
#   'sqft_lot15': 1472},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2040,
#   'sqft_lot': 8076,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 2040,
#   'sqft_basement': 0,
#   'yr_built': 1994,
#   'yr_renovated': 0,
#   'zipcode': 98042,
#   'sqft_living15': 2040,
#   'sqft_lot15': 8408},
#  {'bedrooms': 3,
#   'bathrooms': 1.75,
#   'sqft_living': 2600,
#   'sqft_lot': 105587,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1300,
#   'sqft_basement': 1300,
#   'yr_built': 1980,
#   'yr_renovated': 0,
#   'zipcode': 98070,
#   'sqft_living15': 1941,
#   'sqft_lot15': 208438},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 1080,
#   'sqft_lot': 7486,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 6,
#   'sqft_above': 990,
#   'sqft_basement': 90,
#   'yr_built': 1942,
#   'yr_renovated': 0,
#   'zipcode': 98146,
#   'sqft_living15': 1170,
#   'sqft_lot15': 7800},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 1180,
#   'sqft_lot': 11862,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1180,
#   'sqft_basement': 0,
#   'yr_built': 1948,
#   'yr_renovated': 0,
#   'zipcode': 98177,
#   'sqft_living15': 1540,
#   'sqft_lot15': 8100},
#  {'bedrooms': 1,
#   'bathrooms': 1.0,
#   'sqft_living': 1390,
#   'sqft_lot': 60984,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 6,
#   'sqft_above': 1390,
#   'sqft_basement': 0,
#   'yr_built': 1960,
#   'yr_renovated': 0,
#   'zipcode': 98019,
#   'sqft_living15': 1620,
#   'sqft_lot15': 24225},
#  {'bedrooms': 4,
#   'bathrooms': 1.0,
#   'sqft_living': 2410,
#   'sqft_lot': 6975,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1510,
#   'sqft_basement': 900,
#   'yr_built': 1957,
#   'yr_renovated': 0,
#   'zipcode': 98108,
#   'sqft_living15': 1880,
#   'sqft_lot15': 6255},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2650,
#   'sqft_lot': 7945,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 2650,
#   'sqft_basement': 0,
#   'yr_built': 2006,
#   'yr_renovated': 0,
#   'zipcode': 98125,
#   'sqft_living15': 1200,
#   'sqft_lot15': 7920},
#  {'bedrooms': 4,
#   'bathrooms': 2.25,
#   'sqft_living': 2350,
#   'sqft_lot': 8140,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 8,
#   'sqft_above': 1430,
#   'sqft_basement': 920,
#   'yr_built': 1977,
#   'yr_renovated': 0,
#   'zipcode': 98006,
#   'sqft_living15': 2640,
#   'sqft_lot15': 8700},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2370,
#   'sqft_lot': 10083,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 5,
#   'grade': 8,
#   'sqft_above': 2370,
#   'sqft_basement': 0,
#   'yr_built': 1966,
#   'yr_renovated': 0,
#   'zipcode': 98033,
#   'sqft_living15': 2370,
#   'sqft_lot15': 10133},
#  {'bedrooms': 4,
#   'bathrooms': 2.0,
#   'sqft_living': 1870,
#   'sqft_lot': 6000,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1870,
#   'sqft_basement': 0,
#   'yr_built': 1956,
#   'yr_renovated': 0,
#   'zipcode': 98125,
#   'sqft_living15': 1520,
#   'sqft_lot15': 7169},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 3140,
#   'sqft_lot': 12792,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 9,
#   'sqft_above': 3140,
#   'sqft_basement': 0,
#   'yr_built': 1977,
#   'yr_renovated': 0,
#   'zipcode': 98042,
#   'sqft_living15': 2510,
#   'sqft_lot15': 12792},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 1550,
#   'sqft_lot': 6840,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1550,
#   'sqft_basement': 0,
#   'yr_built': 1918,
#   'yr_renovated': 0,
#   'zipcode': 98103,
#   'sqft_living15': 2370,
#   'sqft_lot15': 4560},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 3170,
#   'sqft_lot': 47502,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 10,
#   'sqft_above': 3170,
#   'sqft_basement': 0,
#   'yr_built': 1988,
#   'yr_renovated': 0,
#   'zipcode': 98033,
#   'sqft_living15': 3190,
#   'sqft_lot15': 35110},
#  {'bedrooms': 3,
#   'bathrooms': 1.5,
#   'sqft_living': 1420,
#   'sqft_lot': 7480,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1420,
#   'sqft_basement': 0,
#   'yr_built': 1963,
#   'yr_renovated': 0,
#   'zipcode': 98058,
#   'sqft_living15': 1720,
#   'sqft_lot15': 7700},
#  {'bedrooms': 3,
#   'bathrooms': 2.25,
#   'sqft_living': 2210,
#   'sqft_lot': 10794,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1540,
#   'sqft_basement': 670,
#   'yr_built': 1967,
#   'yr_renovated': 0,
#   'zipcode': 98178,
#   'sqft_living15': 2230,
#   'sqft_lot15': 10753},
#  {'bedrooms': 5,
#   'bathrooms': 2.25,
#   'sqft_living': 3200,
#   'sqft_lot': 20158,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 1600,
#   'sqft_basement': 1600,
#   'yr_built': 1965,
#   'yr_renovated': 0,
#   'zipcode': 98004,
#   'sqft_living15': 3390,
#   'sqft_lot15': 20158},
#  {'bedrooms': 3,
#   'bathrooms': 1.75,
#   'sqft_living': 1150,
#   'sqft_lot': 9600,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1150,
#   'sqft_basement': 0,
#   'yr_built': 1979,
#   'yr_renovated': 0,
#   'zipcode': 98045,
#   'sqft_living15': 1520,
#   'sqft_lot15': 9976},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 3510,
#   'sqft_lot': 24604,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 10,
#   'sqft_above': 3510,
#   'sqft_basement': 0,
#   'yr_built': 1997,
#   'yr_renovated': 0,
#   'zipcode': 98053,
#   'sqft_living15': 3530,
#   'sqft_lot15': 26673},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 1330,
#   'sqft_lot': 5100,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 900,
#   'sqft_basement': 430,
#   'yr_built': 1942,
#   'yr_renovated': 0,
#   'zipcode': 98115,
#   'sqft_living15': 1500,
#   'sqft_lot15': 5100},
#  {'bedrooms': 3,
#   'bathrooms': 2.25,
#   'sqft_living': 1530,
#   'sqft_lot': 1279,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1116,
#   'sqft_basement': 414,
#   'yr_built': 2007,
#   'yr_renovated': 0,
#   'zipcode': 98177,
#   'sqft_living15': 1320,
#   'sqft_lot15': 1427},
#  {'bedrooms': 5,
#   'bathrooms': 2.25,
#   'sqft_living': 2000,
#   'sqft_lot': 7900,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1300,
#   'sqft_basement': 700,
#   'yr_built': 1986,
#   'yr_renovated': 0,
#   'zipcode': 98188,
#   'sqft_living15': 2000,
#   'sqft_lot15': 9132},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 1280,
#   'sqft_lot': 3200,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1280,
#   'sqft_basement': 0,
#   'yr_built': 1903,
#   'yr_renovated': 0,
#   'zipcode': 98122,
#   'sqft_living15': 1320,
#   'sqft_lot15': 1676},
#  {'bedrooms': 3,
#   'bathrooms': 2.25,
#   'sqft_living': 2700,
#   'sqft_lot': 4025,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 8,
#   'sqft_above': 1760,
#   'sqft_basement': 940,
#   'yr_built': 1907,
#   'yr_renovated': 0,
#   'zipcode': 98122,
#   'sqft_living15': 1580,
#   'sqft_lot15': 4025},
#  {'bedrooms': 3,
#   'bathrooms': 2.5,
#   'sqft_living': 1250,
#   'sqft_lot': 1150,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 1080,
#   'sqft_basement': 170,
#   'yr_built': 2009,
#   'yr_renovated': 0,
#   'zipcode': 98106,
#   'sqft_living15': 1250,
#   'sqft_lot15': 1150},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2070,
#   'sqft_lot': 7007,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 2070,
#   'sqft_basement': 0,
#   'yr_built': 1996,
#   'yr_renovated': 0,
#   'zipcode': 98031,
#   'sqft_living15': 2130,
#   'sqft_lot15': 8100},
#  {'bedrooms': 2,
#   'bathrooms': 2.0,
#   'sqft_living': 1350,
#   'sqft_lot': 2560,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 8,
#   'sqft_above': 1350,
#   'sqft_basement': 0,
#   'yr_built': 1974,
#   'yr_renovated': 0,
#   'zipcode': 98052,
#   'sqft_living15': 1800,
#   'sqft_lot15': 2560},
#  {'bedrooms': 3,
#   'bathrooms': 2.5,
#   'sqft_living': 3110,
#   'sqft_lot': 6000,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 2,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 1560,
#   'sqft_basement': 1550,
#   'yr_built': 1967,
#   'yr_renovated': 0,
#   'zipcode': 98106,
#   'sqft_living15': 2060,
#   'sqft_lot15': 6000},
#  {'bedrooms': 5,
#   'bathrooms': 2.5,
#   'sqft_living': 2840,
#   'sqft_lot': 6010,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 2840,
#   'sqft_basement': 0,
#   'yr_built': 2003,
#   'yr_renovated': 0,
#   'zipcode': 98001,
#   'sqft_living15': 2740,
#   'sqft_lot15': 5509},
#  {'bedrooms': 4,
#   'bathrooms': 3.75,
#   'sqft_living': 3160,
#   'sqft_lot': 9525,
#   'floors': 2.5,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 10,
#   'sqft_above': 3160,
#   'sqft_basement': 0,
#   'yr_built': 1997,
#   'yr_renovated': 0,
#   'zipcode': 98040,
#   'sqft_living15': 2400,
#   'sqft_lot15': 9525},
#  {'bedrooms': 3,
#   'bathrooms': 2.0,
#   'sqft_living': 1640,
#   'sqft_lot': 4714,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 1640,
#   'sqft_basement': 0,
#   'yr_built': 2009,
#   'yr_renovated': 0,
#   'zipcode': 98038,
#   'sqft_living15': 1770,
#   'sqft_lot15': 4802},
#  {'bedrooms': 4,
#   'bathrooms': 1.75,
#   'sqft_living': 2740,
#   'sqft_lot': 10086,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1440,
#   'sqft_basement': 1300,
#   'yr_built': 1972,
#   'yr_renovated': 0,
#   'zipcode': 98168,
#   'sqft_living15': 1710,
#   'sqft_lot15': 9840},
#  {'bedrooms': 4,
#   'bathrooms': 3.5,
#   'sqft_living': 3460,
#   'sqft_lot': 3997,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 10,
#   'sqft_above': 2560,
#   'sqft_basement': 900,
#   'yr_built': 2004,
#   'yr_renovated': 0,
#   'zipcode': 98103,
#   'sqft_living15': 1860,
#   'sqft_lot15': 4000},
#  {'bedrooms': 5,
#   'bathrooms': 1.75,
#   'sqft_living': 1970,
#   'sqft_lot': 8925,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 5,
#   'grade': 7,
#   'sqft_above': 1170,
#   'sqft_basement': 800,
#   'yr_built': 1977,
#   'yr_renovated': 0,
#   'zipcode': 98002,
#   'sqft_living15': 1910,
#   'sqft_lot15': 8025},
#  {'bedrooms': 5,
#   'bathrooms': 3.5,
#   'sqft_living': 3672,
#   'sqft_lot': 9742,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 3006,
#   'sqft_basement': 666,
#   'yr_built': 2006,
#   'yr_renovated': 0,
#   'zipcode': 98092,
#   'sqft_living15': 2140,
#   'sqft_lot15': 9118},
#  {'bedrooms': 4,
#   'bathrooms': 2.0,
#   'sqft_living': 1540,
#   'sqft_lot': 5920,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 5,
#   'grade': 7,
#   'sqft_above': 1540,
#   'sqft_basement': 0,
#   'yr_built': 1935,
#   'yr_renovated': 0,
#   'zipcode': 98125,
#   'sqft_living15': 1630,
#   'sqft_lot15': 6216},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2110,
#   'sqft_lot': 3750,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 2110,
#   'sqft_basement': 0,
#   'yr_built': 2000,
#   'yr_renovated': 0,
#   'zipcode': 98117,
#   'sqft_living15': 1700,
#   'sqft_lot15': 5000},
#  {'bedrooms': 3,
#   'bathrooms': 2.0,
#   'sqft_living': 1630,
#   'sqft_lot': 7599,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 10,
#   'sqft_above': 1630,
#   'sqft_basement': 0,
#   'yr_built': 2006,
#   'yr_renovated': 0,
#   'zipcode': 98117,
#   'sqft_living15': 2030,
#   'sqft_lot15': 7599},
#  {'bedrooms': 4,
#   'bathrooms': 2.25,
#   'sqft_living': 3190,
#   'sqft_lot': 52953,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 10,
#   'sqft_above': 3190,
#   'sqft_basement': 0,
#   'yr_built': 1980,
#   'yr_renovated': 0,
#   'zipcode': 98075,
#   'sqft_living15': 3190,
#   'sqft_lot15': 51400},
#  {'bedrooms': 4,
#   'bathrooms': 3.0,
#   'sqft_living': 4480,
#   'sqft_lot': 42717,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 4480,
#   'sqft_basement': 0,
#   'yr_built': 1987,
#   'yr_renovated': 0,
#   'zipcode': 98077,
#   'sqft_living15': 3140,
#   'sqft_lot15': 41632},
#  {'bedrooms': 3,
#   'bathrooms': 3.25,
#   'sqft_living': 2610,
#   'sqft_lot': 16387,
#   'floors': 2.0,
#   'waterfront': 1,
#   'view': 4,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 2610,
#   'sqft_basement': 0,
#   'yr_built': 2006,
#   'yr_renovated': 0,
#   'zipcode': 98125,
#   'sqft_living15': 2590,
#   'sqft_lot15': 12958},
#  {'bedrooms': 5,
#   'bathrooms': 2.5,
#   'sqft_living': 3390,
#   'sqft_lot': 9760,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 5,
#   'grade': 8,
#   'sqft_above': 1750,
#   'sqft_basement': 1640,
#   'yr_built': 1978,
#   'yr_renovated': 0,
#   'zipcode': 98058,
#   'sqft_living15': 2360,
#   'sqft_lot15': 9600},
#  {'bedrooms': 3,
#   'bathrooms': 1.5,
#   'sqft_living': 1680,
#   'sqft_lot': 17409,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1680,
#   'sqft_basement': 0,
#   'yr_built': 1962,
#   'yr_renovated': 0,
#   'zipcode': 98033,
#   'sqft_living15': 1680,
#   'sqft_lot15': 9101},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2130,
#   'sqft_lot': 9139,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 2130,
#   'sqft_basement': 0,
#   'yr_built': 1988,
#   'yr_renovated': 0,
#   'zipcode': 98029,
#   'sqft_living15': 2150,
#   'sqft_lot15': 8178},
#  {'bedrooms': 3,
#   'bathrooms': 2.5,
#   'sqft_living': 2010,
#   'sqft_lot': 3667,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 2010,
#   'sqft_basement': 0,
#   'yr_built': 2008,
#   'yr_renovated': 0,
#   'zipcode': 98027,
#   'sqft_living15': 2350,
#   'sqft_lot15': 3600},
#  {'bedrooms': 3,
#   'bathrooms': 1.5,
#   'sqft_living': 2390,
#   'sqft_lot': 4452,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 1,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 1790,
#   'sqft_basement': 600,
#   'yr_built': 1929,
#   'yr_renovated': 0,
#   'zipcode': 98126,
#   'sqft_living15': 2610,
#   'sqft_lot15': 5000},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 3910,
#   'sqft_lot': 22710,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 3910,
#   'sqft_basement': 0,
#   'yr_built': 1908,
#   'yr_renovated': 2003,
#   'zipcode': 98004,
#   'sqft_living15': 2920,
#   'sqft_lot15': 16544},
#  {'bedrooms': 3,
#   'bathrooms': 2.5,
#   'sqft_living': 2150,
#   'sqft_lot': 161607,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1330,
#   'sqft_basement': 820,
#   'yr_built': 1995,
#   'yr_renovated': 0,
#   'zipcode': 98038,
#   'sqft_living15': 2400,
#   'sqft_lot15': 207781},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2070,
#   'sqft_lot': 8127,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 1590,
#   'sqft_basement': 480,
#   'yr_built': 1924,
#   'yr_renovated': 2003,
#   'zipcode': 98125,
#   'sqft_living15': 2050,
#   'sqft_lot15': 8131},
#  {'bedrooms': 3,
#   'bathrooms': 2.5,
#   'sqft_living': 2060,
#   'sqft_lot': 2551,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 1900,
#   'sqft_basement': 160,
#   'yr_built': 2001,
#   'yr_renovated': 0,
#   'zipcode': 98005,
#   'sqft_living15': 2060,
#   'sqft_lot15': 2936},
#  {'bedrooms': 3,
#   'bathrooms': 2.25,
#   'sqft_living': 1550,
#   'sqft_lot': 5401,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1550,
#   'sqft_basement': 0,
#   'yr_built': 2000,
#   'yr_renovated': 0,
#   'zipcode': 98019,
#   'sqft_living15': 1740,
#   'sqft_lot15': 4485},
#  {'bedrooms': 3,
#   'bathrooms': 1.75,
#   'sqft_living': 1340,
#   'sqft_lot': 13115,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1340,
#   'sqft_basement': 0,
#   'yr_built': 1978,
#   'yr_renovated': 0,
#   'zipcode': 98045,
#   'sqft_living15': 1370,
#   'sqft_lot15': 10800},
#  {'bedrooms': 4,
#   'bathrooms': 2.25,
#   'sqft_living': 1750,
#   'sqft_lot': 6120,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1150,
#   'sqft_basement': 600,
#   'yr_built': 1962,
#   'yr_renovated': 0,
#   'zipcode': 98115,
#   'sqft_living15': 1350,
#   'sqft_lot15': 6120},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 1150,
#   'sqft_lot': 7486,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1150,
#   'sqft_basement': 0,
#   'yr_built': 1970,
#   'yr_renovated': 0,
#   'zipcode': 98034,
#   'sqft_living15': 1510,
#   'sqft_lot15': 7486},
#  {'bedrooms': 4,
#   'bathrooms': 4.25,
#   'sqft_living': 5584,
#   'sqft_lot': 68257,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 11,
#   'sqft_above': 5584,
#   'sqft_basement': 0,
#   'yr_built': 1998,
#   'yr_renovated': 0,
#   'zipcode': 98014,
#   'sqft_living15': 5030,
#   'sqft_lot15': 101901},
#  {'bedrooms': 3,
#   'bathrooms': 2.5,
#   'sqft_living': 2690,
#   'sqft_lot': 4819,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 2690,
#   'sqft_basement': 0,
#   'yr_built': 2004,
#   'yr_renovated': 0,
#   'zipcode': 98065,
#   'sqft_living15': 2360,
#   'sqft_lot15': 4829},
#  {'bedrooms': 3,
#   'bathrooms': 2.75,
#   'sqft_living': 2390,
#   'sqft_lot': 9966,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 5,
#   'grade': 8,
#   'sqft_above': 1360,
#   'sqft_basement': 1030,
#   'yr_built': 1977,
#   'yr_renovated': 0,
#   'zipcode': 98006,
#   'sqft_living15': 2140,
#   'sqft_lot15': 10713},
#  {'bedrooms': 4,
#   'bathrooms': 1.75,
#   'sqft_living': 2320,
#   'sqft_lot': 4322,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1140,
#   'sqft_basement': 1180,
#   'yr_built': 1910,
#   'yr_renovated': 0,
#   'zipcode': 98144,
#   'sqft_living15': 1820,
#   'sqft_lot15': 4322},
#  {'bedrooms': 4,
#   'bathrooms': 4.0,
#   'sqft_living': 4810,
#   'sqft_lot': 18851,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 3,
#   'condition': 3,
#   'grade': 11,
#   'sqft_above': 4810,
#   'sqft_basement': 0,
#   'yr_built': 2007,
#   'yr_renovated': 0,
#   'zipcode': 98004,
#   'sqft_living15': 3970,
#   'sqft_lot15': 19929},
#  {'bedrooms': 2,
#   'bathrooms': 2.25,
#   'sqft_living': 1610,
#   'sqft_lot': 2040,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1610,
#   'sqft_basement': 0,
#   'yr_built': 1979,
#   'yr_renovated': 0,
#   'zipcode': 98056,
#   'sqft_living15': 1950,
#   'sqft_lot15': 2025},
#  {'bedrooms': 3,
#   'bathrooms': 2.25,
#   'sqft_living': 2080,
#   'sqft_lot': 12134,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 8,
#   'sqft_above': 1530,
#   'sqft_basement': 550,
#   'yr_built': 1973,
#   'yr_renovated': 0,
#   'zipcode': 98052,
#   'sqft_living15': 2320,
#   'sqft_lot15': 12400},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2710,
#   'sqft_lot': 49044,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 2710,
#   'sqft_basement': 0,
#   'yr_built': 1988,
#   'yr_renovated': 0,
#   'zipcode': 98077,
#   'sqft_living15': 2560,
#   'sqft_lot15': 38190},
#  {'bedrooms': 3,
#   'bathrooms': 1.75,
#   'sqft_living': 1530,
#   'sqft_lot': 8503,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1150,
#   'sqft_basement': 380,
#   'yr_built': 1983,
#   'yr_renovated': 0,
#   'zipcode': 98033,
#   'sqft_living15': 1610,
#   'sqft_lot15': 8549},
#  {'bedrooms': 4,
#   'bathrooms': 3.0,
#   'sqft_living': 2130,
#   'sqft_lot': 4838,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 2130,
#   'sqft_basement': 0,
#   'yr_built': 1930,
#   'yr_renovated': 0,
#   'zipcode': 98055,
#   'sqft_living15': 1070,
#   'sqft_lot15': 4838},
#  {'bedrooms': 3,
#   'bathrooms': 1.5,
#   'sqft_living': 1200,
#   'sqft_lot': 9120,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1000,
#   'sqft_basement': 200,
#   'yr_built': 1963,
#   'yr_renovated': 0,
#   'zipcode': 98055,
#   'sqft_living15': 1640,
#   'sqft_lot15': 9200},
#  {'bedrooms': 3,
#   'bathrooms': 1.5,
#   'sqft_living': 2390,
#   'sqft_lot': 4600,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 1750,
#   'sqft_basement': 640,
#   'yr_built': 1920,
#   'yr_renovated': 1995,
#   'zipcode': 98118,
#   'sqft_living15': 1690,
#   'sqft_lot15': 5220},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2500,
#   'sqft_lot': 4945,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 2500,
#   'sqft_basement': 0,
#   'yr_built': 2013,
#   'yr_renovated': 0,
#   'zipcode': 98065,
#   'sqft_living15': 2760,
#   'sqft_lot15': 6000},
#  {'bedrooms': 4,
#   'bathrooms': 3.25,
#   'sqft_living': 4060,
#   'sqft_lot': 13000,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 3,
#   'condition': 3,
#   'grade': 11,
#   'sqft_above': 4060,
#   'sqft_basement': 0,
#   'yr_built': 2000,
#   'yr_renovated': 0,
#   'zipcode': 98040,
#   'sqft_living15': 3220,
#   'sqft_lot15': 13800},
#  {'bedrooms': 3,
#   'bathrooms': 1.75,
#   'sqft_living': 1700,
#   'sqft_lot': 8534,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1700,
#   'sqft_basement': 0,
#   'yr_built': 1953,
#   'yr_renovated': 0,
#   'zipcode': 98004,
#   'sqft_living15': 2100,
#   'sqft_lot15': 10443},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2430,
#   'sqft_lot': 6796,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 2430,
#   'sqft_basement': 0,
#   'yr_built': 1993,
#   'yr_renovated': 0,
#   'zipcode': 98058,
#   'sqft_living15': 2450,
#   'sqft_lot15': 8400},
#  {'bedrooms': 3,
#   'bathrooms': 2.5,
#   'sqft_living': 1940,
#   'sqft_lot': 9874,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1940,
#   'sqft_basement': 0,
#   'yr_built': 1990,
#   'yr_renovated': 0,
#   'zipcode': 98042,
#   'sqft_living15': 1860,
#   'sqft_lot15': 8875},
#  {'bedrooms': 2,
#   'bathrooms': 2.25,
#   'sqft_living': 2210,
#   'sqft_lot': 5500,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 8,
#   'sqft_above': 1410,
#   'sqft_basement': 800,
#   'yr_built': 1968,
#   'yr_renovated': 0,
#   'zipcode': 98117,
#   'sqft_living15': 2140,
#   'sqft_lot15': 6600},
#  {'bedrooms': 2,
#   'bathrooms': 1.0,
#   'sqft_living': 1120,
#   'sqft_lot': 4590,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1120,
#   'sqft_basement': 0,
#   'yr_built': 1924,
#   'yr_renovated': 0,
#   'zipcode': 98118,
#   'sqft_living15': 1120,
#   'sqft_lot15': 5100},
#  {'bedrooms': 2,
#   'bathrooms': 1.5,
#   'sqft_living': 1820,
#   'sqft_lot': 8867,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1820,
#   'sqft_basement': 0,
#   'yr_built': 1921,
#   'yr_renovated': 0,
#   'zipcode': 98168,
#   'sqft_living15': 1430,
#   'sqft_lot15': 9288},
#  {'bedrooms': 3,
#   'bathrooms': 1.75,
#   'sqft_living': 1920,
#   'sqft_lot': 5405,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 2,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 960,
#   'sqft_basement': 960,
#   'yr_built': 1947,
#   'yr_renovated': 0,
#   'zipcode': 98126,
#   'sqft_living15': 1190,
#   'sqft_lot15': 5405},
#  {'bedrooms': 5,
#   'bathrooms': 2.75,
#   'sqft_living': 3040,
#   'sqft_lot': 10257,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 10,
#   'sqft_above': 3040,
#   'sqft_basement': 0,
#   'yr_built': 1993,
#   'yr_renovated': 0,
#   'zipcode': 98006,
#   'sqft_living15': 2860,
#   'sqft_lot15': 9327},
#  {'bedrooms': 4,
#   'bathrooms': 1.0,
#   'sqft_living': 1010,
#   'sqft_lot': 7515,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 6,
#   'sqft_above': 1010,
#   'sqft_basement': 0,
#   'yr_built': 1955,
#   'yr_renovated': 0,
#   'zipcode': 98198,
#   'sqft_living15': 1330,
#   'sqft_lot15': 7515},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 3000,
#   'sqft_lot': 5471,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 3000,
#   'sqft_basement': 0,
#   'yr_built': 2013,
#   'yr_renovated': 0,
#   'zipcode': 98059,
#   'sqft_living15': 2730,
#   'sqft_lot15': 5471},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2490,
#   'sqft_lot': 5812,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 2490,
#   'sqft_basement': 0,
#   'yr_built': 2000,
#   'yr_renovated': 0,
#   'zipcode': 98042,
#   'sqft_living15': 2690,
#   'sqft_lot15': 6012},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 3160,
#   'sqft_lot': 39960,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 10,
#   'sqft_above': 3160,
#   'sqft_basement': 0,
#   'yr_built': 1980,
#   'yr_renovated': 0,
#   'zipcode': 98005,
#   'sqft_living15': 3900,
#   'sqft_lot15': 36444},
#  {'bedrooms': 3,
#   'bathrooms': 2.5,
#   'sqft_living': 1600,
#   'sqft_lot': 3172,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1600,
#   'sqft_basement': 0,
#   'yr_built': 2002,
#   'yr_renovated': 0,
#   'zipcode': 98053,
#   'sqft_living15': 1690,
#   'sqft_lot15': 3698},
#  {'bedrooms': 4,
#   'bathrooms': 1.5,
#   'sqft_living': 1740,
#   'sqft_lot': 8160,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1400,
#   'sqft_basement': 340,
#   'yr_built': 1946,
#   'yr_renovated': 0,
#   'zipcode': 98177,
#   'sqft_living15': 1600,
#   'sqft_lot15': 8160},
#  {'bedrooms': 3,
#   'bathrooms': 2.0,
#   'sqft_living': 1660,
#   'sqft_lot': 3600,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1000,
#   'sqft_basement': 660,
#   'yr_built': 1939,
#   'yr_renovated': 2006,
#   'zipcode': 98103,
#   'sqft_living15': 1700,
#   'sqft_lot15': 4356},
#  {'bedrooms': 5,
#   'bathrooms': 2.75,
#   'sqft_living': 3600,
#   'sqft_lot': 9437,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 3600,
#   'sqft_basement': 0,
#   'yr_built': 2014,
#   'yr_renovated': 0,
#   'zipcode': 98059,
#   'sqft_living15': 3550,
#   'sqft_lot15': 9421},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 1847,
#   'sqft_lot': 8000,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1847,
#   'sqft_basement': 0,
#   'yr_built': 2008,
#   'yr_renovated': 0,
#   'zipcode': 98001,
#   'sqft_living15': 1767,
#   'sqft_lot15': 8000},
#  {'bedrooms': 3,
#   'bathrooms': 2.5,
#   'sqft_living': 1710,
#   'sqft_lot': 6773,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 1710,
#   'sqft_basement': 0,
#   'yr_built': 1993,
#   'yr_renovated': 0,
#   'zipcode': 98003,
#   'sqft_living15': 2220,
#   'sqft_lot15': 7551},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 1160,
#   'sqft_lot': 3700,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1160,
#   'sqft_basement': 0,
#   'yr_built': 1909,
#   'yr_renovated': 0,
#   'zipcode': 98106,
#   'sqft_living15': 1340,
#   'sqft_lot15': 3750},
#  {'bedrooms': 5,
#   'bathrooms': 3.5,
#   'sqft_living': 3960,
#   'sqft_lot': 25245,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 2500,
#   'sqft_basement': 1460,
#   'yr_built': 1996,
#   'yr_renovated': 0,
#   'zipcode': 98056,
#   'sqft_living15': 2640,
#   'sqft_lot15': 13675},
#  {'bedrooms': 2,
#   'bathrooms': 2.25,
#   'sqft_living': 1230,
#   'sqft_lot': 929,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 1020,
#   'sqft_basement': 210,
#   'yr_built': 2004,
#   'yr_renovated': 0,
#   'zipcode': 98122,
#   'sqft_living15': 1270,
#   'sqft_lot15': 1370},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 1200,
#   'sqft_lot': 8470,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 5,
#   'grade': 7,
#   'sqft_above': 1200,
#   'sqft_basement': 0,
#   'yr_built': 1961,
#   'yr_renovated': 0,
#   'zipcode': 98032,
#   'sqft_living15': 1200,
#   'sqft_lot15': 7952},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 810,
#   'sqft_lot': 5240,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 6,
#   'sqft_above': 810,
#   'sqft_basement': 0,
#   'yr_built': 1942,
#   'yr_renovated': 0,
#   'zipcode': 98166,
#   'sqft_living15': 1700,
#   'sqft_lot15': 5245},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2080,
#   'sqft_lot': 4080,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 5,
#   'grade': 7,
#   'sqft_above': 1040,
#   'sqft_basement': 1040,
#   'yr_built': 1962,
#   'yr_renovated': 0,
#   'zipcode': 98144,
#   'sqft_living15': 1340,
#   'sqft_lot15': 4080},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 950,
#   'sqft_lot': 5214,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 830,
#   'sqft_basement': 120,
#   'yr_built': 1944,
#   'yr_renovated': 0,
#   'zipcode': 98126,
#   'sqft_living15': 1490,
#   'sqft_lot15': 7636},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 950,
#   'sqft_lot': 4500,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 6,
#   'sqft_above': 950,
#   'sqft_basement': 0,
#   'yr_built': 1943,
#   'yr_renovated': 0,
#   'zipcode': 98118,
#   'sqft_living15': 1140,
#   'sqft_lot15': 4500},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2880,
#   'sqft_lot': 23994,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 3,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 2880,
#   'sqft_basement': 0,
#   'yr_built': 2002,
#   'yr_renovated': 0,
#   'zipcode': 98022,
#   'sqft_living15': 2470,
#   'sqft_lot15': 17009},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 980,
#   'sqft_lot': 4800,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 980,
#   'sqft_basement': 0,
#   'yr_built': 1926,
#   'yr_renovated': 0,
#   'zipcode': 98118,
#   'sqft_living15': 2030,
#   'sqft_lot15': 7200},
#  {'bedrooms': 2,
#   'bathrooms': 1.0,
#   'sqft_living': 1140,
#   'sqft_lot': 8340,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1140,
#   'sqft_basement': 0,
#   'yr_built': 1948,
#   'yr_renovated': 0,
#   'zipcode': 98155,
#   'sqft_living15': 1030,
#   'sqft_lot15': 8149},
#  {'bedrooms': 4,
#   'bathrooms': 1.5,
#   'sqft_living': 1240,
#   'sqft_lot': 9600,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1240,
#   'sqft_basement': 0,
#   'yr_built': 1971,
#   'yr_renovated': 0,
#   'zipcode': 98023,
#   'sqft_living15': 1240,
#   'sqft_lot15': 9592},
#  {'bedrooms': 5,
#   'bathrooms': 2.5,
#   'sqft_living': 2140,
#   'sqft_lot': 15950,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 2,
#   'condition': 4,
#   'grade': 8,
#   'sqft_above': 1370,
#   'sqft_basement': 770,
#   'yr_built': 1968,
#   'yr_renovated': 0,
#   'zipcode': 98166,
#   'sqft_living15': 2600,
#   'sqft_lot15': 14273},
#  {'bedrooms': 4,
#   'bathrooms': 2.0,
#   'sqft_living': 1760,
#   'sqft_lot': 7700,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1760,
#   'sqft_basement': 0,
#   'yr_built': 1962,
#   'yr_renovated': 0,
#   'zipcode': 98003,
#   'sqft_living15': 1870,
#   'sqft_lot15': 7316},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2740,
#   'sqft_lot': 5700,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 2740,
#   'sqft_basement': 0,
#   'yr_built': 2006,
#   'yr_renovated': 0,
#   'zipcode': 98038,
#   'sqft_living15': 3010,
#   'sqft_lot15': 5281},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 1050,
#   'sqft_lot': 7670,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 5,
#   'grade': 7,
#   'sqft_above': 1050,
#   'sqft_basement': 0,
#   'yr_built': 1955,
#   'yr_renovated': 0,
#   'zipcode': 98022,
#   'sqft_living15': 1220,
#   'sqft_lot15': 7670},
#  {'bedrooms': 3,
#   'bathrooms': 2.5,
#   'sqft_living': 1370,
#   'sqft_lot': 22326,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1370,
#   'sqft_basement': 0,
#   'yr_built': 1993,
#   'yr_renovated': 0,
#   'zipcode': 98045,
#   'sqft_living15': 1580,
#   'sqft_lot15': 10920},
#  {'bedrooms': 4,
#   'bathrooms': 1.75,
#   'sqft_living': 2010,
#   'sqft_lot': 12044,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 2010,
#   'sqft_basement': 0,
#   'yr_built': 1982,
#   'yr_renovated': 0,
#   'zipcode': 98074,
#   'sqft_living15': 2200,
#   'sqft_lot15': 11144},
#  {'bedrooms': 3,
#   'bathrooms': 2.25,
#   'sqft_living': 2800,
#   'sqft_lot': 35362,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 2800,
#   'sqft_basement': 0,
#   'yr_built': 1985,
#   'yr_renovated': 0,
#   'zipcode': 98042,
#   'sqft_living15': 2800,
#   'sqft_lot15': 37058},
#  {'bedrooms': 4,
#   'bathrooms': 2.0,
#   'sqft_living': 1450,
#   'sqft_lot': 8175,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1450,
#   'sqft_basement': 0,
#   'yr_built': 1967,
#   'yr_renovated': 0,
#   'zipcode': 98031,
#   'sqft_living15': 1570,
#   'sqft_lot15': 9024},
#  {'bedrooms': 3,
#   'bathrooms': 2.75,
#   'sqft_living': 2590,
#   'sqft_lot': 12063,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 10,
#   'sqft_above': 2590,
#   'sqft_basement': 0,
#   'yr_built': 1993,
#   'yr_renovated': 0,
#   'zipcode': 98006,
#   'sqft_living15': 2850,
#   'sqft_lot15': 8469},
#  {'bedrooms': 4,
#   'bathrooms': 1.0,
#   'sqft_living': 1860,
#   'sqft_lot': 8505,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1860,
#   'sqft_basement': 0,
#   'yr_built': 1955,
#   'yr_renovated': 0,
#   'zipcode': 98055,
#   'sqft_living15': 1560,
#   'sqft_lot15': 8505},
#  {'bedrooms': 3,
#   'bathrooms': 1.75,
#   'sqft_living': 1310,
#   'sqft_lot': 9645,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1310,
#   'sqft_basement': 0,
#   'yr_built': 1979,
#   'yr_renovated': 0,
#   'zipcode': 98198,
#   'sqft_living15': 1440,
#   'sqft_lot15': 9893},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2680,
#   'sqft_lot': 5539,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 2680,
#   'sqft_basement': 0,
#   'yr_built': 2013,
#   'yr_renovated': 0,
#   'zipcode': 98045,
#   'sqft_living15': 2680,
#   'sqft_lot15': 5992},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 3000,
#   'sqft_lot': 8100,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 3000,
#   'sqft_basement': 0,
#   'yr_built': 1992,
#   'yr_renovated': 0,
#   'zipcode': 98125,
#   'sqft_living15': 1550,
#   'sqft_lot15': 8100},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 1960,
#   'sqft_lot': 11600,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 5,
#   'grade': 6,
#   'sqft_above': 980,
#   'sqft_basement': 980,
#   'yr_built': 1931,
#   'yr_renovated': 0,
#   'zipcode': 98002,
#   'sqft_living15': 1160,
#   'sqft_lot15': 7685},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2040,
#   'sqft_lot': 5616,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 2040,
#   'sqft_basement': 0,
#   'yr_built': 2012,
#   'yr_renovated': 0,
#   'zipcode': 98028,
#   'sqft_living15': 2380,
#   'sqft_lot15': 4737},
#  {'bedrooms': 3,
#   'bathrooms': 2.25,
#   'sqft_living': 1200,
#   'sqft_lot': 1400,
#   'floors': 3.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 1200,
#   'sqft_basement': 0,
#   'yr_built': 2005,
#   'yr_renovated': 0,
#   'zipcode': 98133,
#   'sqft_living15': 1370,
#   'sqft_lot15': 6552},
#  {'bedrooms': 4,
#   'bathrooms': 3.25,
#   'sqft_living': 3720,
#   'sqft_lot': 6765,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 3720,
#   'sqft_basement': 0,
#   'yr_built': 2012,
#   'yr_renovated': 0,
#   'zipcode': 98053,
#   'sqft_living15': 3100,
#   'sqft_lot15': 6790},
#  {'bedrooms': 4,
#   'bathrooms': 2.75,
#   'sqft_living': 2610,
#   'sqft_lot': 8967,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 8,
#   'sqft_above': 2610,
#   'sqft_basement': 0,
#   'yr_built': 1990,
#   'yr_renovated': 0,
#   'zipcode': 98042,
#   'sqft_living15': 2390,
#   'sqft_lot15': 7852},
# ...
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1360,
#   'sqft_basement': 600,
#   'yr_built': 1969,
#   'yr_renovated': 0,
#   'zipcode': 98058,
#   'sqft_living15': 1900,
#   'sqft_lot15': 7350},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 3480,
#   'sqft_lot': 6262,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 3480,
#   'sqft_basement': 0,
#   'yr_built': 2003,
#   'yr_renovated': 0,
#   'zipcode': 98053,
#   'sqft_living15': 3490,
#   'sqft_lot15': 6629},
#  {'bedrooms': 4,
#   'bathrooms': 1.0,
#   'sqft_living': 1030,
#   'sqft_lot': 5750,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1030,
#   'sqft_basement': 0,
#   'yr_built': 1971,
#   'yr_renovated': 0,
#   'zipcode': 98126,
#   'sqft_living15': 1250,
#   'sqft_lot15': 5750},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2760,
#   'sqft_lot': 5000,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 5,
#   'grade': 7,
#   'sqft_above': 1680,
#   'sqft_basement': 1080,
#   'yr_built': 1928,
#   'yr_renovated': 0,
#   'zipcode': 98107,
#   'sqft_living15': 1850,
#   'sqft_lot15': 5000},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2340,
#   'sqft_lot': 5420,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 2340,
#   'sqft_basement': 0,
#   'yr_built': 2003,
#   'yr_renovated': 0,
#   'zipcode': 98038,
#   'sqft_living15': 2420,
#   'sqft_lot15': 6252},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2460,
#   'sqft_lot': 5091,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 2460,
#   'sqft_basement': 0,
#   'yr_built': 2003,
#   'yr_renovated': 0,
#   'zipcode': 98058,
#   'sqft_living15': 2490,
#   'sqft_lot15': 4750},
#  {'bedrooms': 3,
#   'bathrooms': 3.25,
#   'sqft_living': 1450,
#   'sqft_lot': 1387,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 1180,
#   'sqft_basement': 270,
#   'yr_built': 2013,
#   'yr_renovated': 0,
#   'zipcode': 98106,
#   'sqft_living15': 1450,
#   'sqft_lot15': 1198},
#  {'bedrooms': 3,
#   'bathrooms': 1.75,
#   'sqft_living': 1880,
#   'sqft_lot': 8424,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1380,
#   'sqft_basement': 500,
#   'yr_built': 1977,
#   'yr_renovated': 0,
#   'zipcode': 98059,
#   'sqft_living15': 1970,
#   'sqft_lot15': 8523},
#  {'bedrooms': 5,
#   'bathrooms': 2.0,
#   'sqft_living': 2560,
#   'sqft_lot': 14467,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 1280,
#   'sqft_basement': 1280,
#   'yr_built': 1960,
#   'yr_renovated': 0,
#   'zipcode': 98006,
#   'sqft_living15': 2200,
#   'sqft_lot15': 10267},
#  {'bedrooms': 3,
#   'bathrooms': 2.5,
#   'sqft_living': 2340,
#   'sqft_lot': 6837,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 2340,
#   'sqft_basement': 0,
#   'yr_built': 1992,
#   'yr_renovated': 0,
#   'zipcode': 98030,
#   'sqft_living15': 1850,
#   'sqft_lot15': 6209},
#  {'bedrooms': 3,
#   'bathrooms': 3.0,
#   'sqft_living': 4230,
#   'sqft_lot': 54977,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 3,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 3780,
#   'sqft_basement': 450,
#   'yr_built': 1951,
#   'yr_renovated': 2000,
#   'zipcode': 98166,
#   'sqft_living15': 2880,
#   'sqft_lot15': 27201},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 4070,
#   'sqft_lot': 57587,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 10,
#   'sqft_above': 4070,
#   'sqft_basement': 0,
#   'yr_built': 1989,
#   'yr_renovated': 0,
#   'zipcode': 98052,
#   'sqft_living15': 3890,
#   'sqft_lot15': 35960},
#  {'bedrooms': 3,
#   'bathrooms': 2.5,
#   'sqft_living': 2270,
#   'sqft_lot': 7887,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 2,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 2270,
#   'sqft_basement': 0,
#   'yr_built': 2004,
#   'yr_renovated': 0,
#   'zipcode': 98065,
#   'sqft_living15': 2550,
#   'sqft_lot15': 7133},
#  {'bedrooms': 4,
#   'bathrooms': 1.5,
#   'sqft_living': 1700,
#   'sqft_lot': 8400,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1700,
#   'sqft_basement': 0,
#   'yr_built': 1953,
#   'yr_renovated': 0,
#   'zipcode': 98177,
#   'sqft_living15': 1750,
#   'sqft_lot15': 8475},
#  {'bedrooms': 3,
#   'bathrooms': 1.75,
#   'sqft_living': 1780,
#   'sqft_lot': 37801,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1300,
#   'sqft_basement': 480,
#   'yr_built': 1977,
#   'yr_renovated': 0,
#   'zipcode': 98075,
#   'sqft_living15': 2380,
#   'sqft_lot15': 47480},
#  {'bedrooms': 3,
#   'bathrooms': 2.0,
#   'sqft_living': 1430,
#   'sqft_lot': 12430,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1430,
#   'sqft_basement': 0,
#   'yr_built': 1957,
#   'yr_renovated': 0,
#   'zipcode': 98056,
#   'sqft_living15': 1200,
#   'sqft_lot15': 8250},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 1320,
#   'sqft_lot': 24684,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1320,
#   'sqft_basement': 0,
#   'yr_built': 1979,
#   'yr_renovated': 0,
#   'zipcode': 98168,
#   'sqft_living15': 1120,
#   'sqft_lot15': 21214},
#  {'bedrooms': 3,
#   'bathrooms': 2.5,
#   'sqft_living': 1610,
#   'sqft_lot': 8064,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 2,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1160,
#   'sqft_basement': 450,
#   'yr_built': 1981,
#   'yr_renovated': 0,
#   'zipcode': 98033,
#   'sqft_living15': 2260,
#   'sqft_lot15': 8328},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 1290,
#   'sqft_lot': 9526,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1290,
#   'sqft_basement': 0,
#   'yr_built': 1961,
#   'yr_renovated': 0,
#   'zipcode': 98034,
#   'sqft_living15': 1290,
#   'sqft_lot15': 9508},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 1140,
#   'sqft_lot': 8400,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1140,
#   'sqft_basement': 0,
#   'yr_built': 1960,
#   'yr_renovated': 0,
#   'zipcode': 98059,
#   'sqft_living15': 1400,
#   'sqft_lot15': 9000},
#  {'bedrooms': 3,
#   'bathrooms': 2.5,
#   'sqft_living': 2280,
#   'sqft_lot': 2296,
#   'floors': 3.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 1890,
#   'sqft_basement': 390,
#   'yr_built': 2013,
#   'yr_renovated': 0,
#   'zipcode': 98112,
#   'sqft_living15': 1390,
#   'sqft_lot15': 4000},
#  {'bedrooms': 4,
#   'bathrooms': 3.75,
#   'sqft_living': 4100,
#   'sqft_lot': 22798,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 3,
#   'condition': 5,
#   'grade': 11,
#   'sqft_above': 2540,
#   'sqft_basement': 1560,
#   'yr_built': 1934,
#   'yr_renovated': 1979,
#   'zipcode': 98040,
#   'sqft_living15': 3880,
#   'sqft_lot15': 18730},
#  {'bedrooms': 5,
#   'bathrooms': 2.5,
#   'sqft_living': 2890,
#   'sqft_lot': 5110,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 2,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 2890,
#   'sqft_basement': 0,
#   'yr_built': 2003,
#   'yr_renovated': 0,
#   'zipcode': 98029,
#   'sqft_living15': 3010,
#   'sqft_lot15': 5110},
#  {'bedrooms': 3,
#   'bathrooms': 2.0,
#   'sqft_living': 1470,
#   'sqft_lot': 2781,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 6,
#   'sqft_above': 1470,
#   'sqft_basement': 0,
#   'yr_built': 2003,
#   'yr_renovated': 0,
#   'zipcode': 98038,
#   'sqft_living15': 1360,
#   'sqft_lot15': 3008},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2200,
#   'sqft_lot': 3141,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 2060,
#   'sqft_basement': 140,
#   'yr_built': 1994,
#   'yr_renovated': 0,
#   'zipcode': 98144,
#   'sqft_living15': 1660,
#   'sqft_lot15': 3175},
#  {'bedrooms': 4,
#   'bathrooms': 3.0,
#   'sqft_living': 2040,
#   'sqft_lot': 5050,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 1490,
#   'sqft_basement': 550,
#   'yr_built': 1993,
#   'yr_renovated': 0,
#   'zipcode': 98092,
#   'sqft_living15': 2020,
#   'sqft_lot15': 6118},
#  {'bedrooms': 4,
#   'bathrooms': 3.5,
#   'sqft_living': 3010,
#   'sqft_lot': 6202,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 3010,
#   'sqft_basement': 0,
#   'yr_built': 2005,
#   'yr_renovated': 0,
#   'zipcode': 98029,
#   'sqft_living15': 2520,
#   'sqft_lot15': 5001},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 1010,
#   'sqft_lot': 12705,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1010,
#   'sqft_basement': 0,
#   'yr_built': 1959,
#   'yr_renovated': 0,
#   'zipcode': 98003,
#   'sqft_living15': 1490,
#   'sqft_lot15': 10200},
#  {'bedrooms': 4,
#   'bathrooms': 2.75,
#   'sqft_living': 2630,
#   'sqft_lot': 7505,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 2630,
#   'sqft_basement': 0,
#   'yr_built': 1994,
#   'yr_renovated': 0,
#   'zipcode': 98052,
#   'sqft_living15': 2670,
#   'sqft_lot15': 7506},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 3080,
#   'sqft_lot': 35430,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 3080,
#   'sqft_basement': 0,
#   'yr_built': 1997,
#   'yr_renovated': 0,
#   'zipcode': 98053,
#   'sqft_living15': 2640,
#   'sqft_lot15': 28972},
#  {'bedrooms': 3,
#   'bathrooms': 1.75,
#   'sqft_living': 1740,
#   'sqft_lot': 8528,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1290,
#   'sqft_basement': 450,
#   'yr_built': 1939,
#   'yr_renovated': 0,
#   'zipcode': 98125,
#   'sqft_living15': 1610,
#   'sqft_lot15': 8528},
#  {'bedrooms': 3,
#   'bathrooms': 2.25,
#   'sqft_living': 2930,
#   'sqft_lot': 7005,
#   'floors': 3.0,
#   'waterfront': 0,
#   'view': 2,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 2670,
#   'sqft_basement': 260,
#   'yr_built': 1999,
#   'yr_renovated': 0,
#   'zipcode': 98117,
#   'sqft_living15': 2450,
#   'sqft_lot15': 6460},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 3220,
#   'sqft_lot': 35400,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 9,
#   'sqft_above': 3220,
#   'sqft_basement': 0,
#   'yr_built': 1991,
#   'yr_renovated': 0,
#   'zipcode': 98072,
#   'sqft_living15': 3050,
#   'sqft_lot15': 35252},
#  {'bedrooms': 3,
#   'bathrooms': 1.5,
#   'sqft_living': 1540,
#   'sqft_lot': 3570,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 5,
#   'grade': 7,
#   'sqft_above': 1490,
#   'sqft_basement': 50,
#   'yr_built': 1930,
#   'yr_renovated': 0,
#   'zipcode': 98105,
#   'sqft_living15': 1620,
#   'sqft_lot15': 4080},
#  {'bedrooms': 4,
#   'bathrooms': 1.5,
#   'sqft_living': 2120,
#   'sqft_lot': 46173,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 2120,
#   'sqft_basement': 0,
#   'yr_built': 1974,
#   'yr_renovated': 0,
#   'zipcode': 98053,
#   'sqft_living15': 2000,
#   'sqft_lot15': 46173},
#  {'bedrooms': 3,
#   'bathrooms': 1.75,
#   'sqft_living': 1010,
#   'sqft_lot': 5355,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 6,
#   'sqft_above': 1010,
#   'sqft_basement': 0,
#   'yr_built': 1950,
#   'yr_renovated': 0,
#   'zipcode': 98106,
#   'sqft_living15': 750,
#   'sqft_lot15': 4515},
#  {'bedrooms': 3,
#   'bathrooms': 1.75,
#   'sqft_living': 1460,
#   'sqft_lot': 9261,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1460,
#   'sqft_basement': 0,
#   'yr_built': 1985,
#   'yr_renovated': 0,
#   'zipcode': 98056,
#   'sqft_living15': 1550,
#   'sqft_lot15': 8800},
#  {'bedrooms': 4,
#   'bathrooms': 2.75,
#   'sqft_living': 3460,
#   'sqft_lot': 11350,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 4,
#   'condition': 4,
#   'grade': 9,
#   'sqft_above': 1780,
#   'sqft_basement': 1680,
#   'yr_built': 1974,
#   'yr_renovated': 0,
#   'zipcode': 98006,
#   'sqft_living15': 3200,
#   'sqft_lot15': 13874},
#  {'bedrooms': 4,
#   'bathrooms': 2.75,
#   'sqft_living': 3880,
#   'sqft_lot': 15025,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 3880,
#   'sqft_basement': 0,
#   'yr_built': 2004,
#   'yr_renovated': 0,
#   'zipcode': 98053,
#   'sqft_living15': 2620,
#   'sqft_lot15': 5300},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2190,
#   'sqft_lot': 17600,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 7,
#   'sqft_above': 1110,
#   'sqft_basement': 1080,
#   'yr_built': 1966,
#   'yr_renovated': 0,
#   'zipcode': 98059,
#   'sqft_living15': 1820,
#   'sqft_lot15': 17600},
#  {'bedrooms': 3,
#   'bathrooms': 2.0,
#   'sqft_living': 1550,
#   'sqft_lot': 8300,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 8,
#   'sqft_above': 1550,
#   'sqft_basement': 0,
#   'yr_built': 1965,
#   'yr_renovated': 0,
#   'zipcode': 98055,
#   'sqft_living15': 1860,
#   'sqft_lot15': 8000},
#  {'bedrooms': 3,
#   'bathrooms': 2.0,
#   'sqft_living': 1730,
#   'sqft_lot': 6007,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 8,
#   'sqft_above': 1730,
#   'sqft_basement': 0,
#   'yr_built': 2004,
#   'yr_renovated': 0,
#   'zipcode': 98030,
#   'sqft_living15': 2000,
#   'sqft_lot15': 6245},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 2040,
#   'sqft_lot': 5000,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 5,
#   'grade': 7,
#   'sqft_above': 1180,
#   'sqft_basement': 860,
#   'yr_built': 1924,
#   'yr_renovated': 0,
#   'zipcode': 98117,
#   'sqft_living15': 1540,
#   'sqft_lot15': 5000},
#  {'bedrooms': 3,
#   'bathrooms': 1.75,
#   'sqft_living': 2190,
#   'sqft_lot': 3800,
#   'floors': 1.5,
#   'waterfront': 0,
#   'view': 2,
#   'condition': 4,
#   'grade': 8,
#   'sqft_above': 2190,
#   'sqft_basement': 0,
#   'yr_built': 1923,
#   'yr_renovated': 0,
#   'zipcode': 98109,
#   'sqft_living15': 2190,
#   'sqft_lot15': 3880},
#  {'bedrooms': 3,
#   'bathrooms': 1.5,
#   'sqft_living': 1890,
#   'sqft_lot': 9450,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1090,
#   'sqft_basement': 800,
#   'yr_built': 1957,
#   'yr_renovated': 0,
#   'zipcode': 98146,
#   'sqft_living15': 1470,
#   'sqft_lot15': 8100},
#  {'bedrooms': 3,
#   'bathrooms': 1.5,
#   'sqft_living': 1280,
#   'sqft_lot': 4366,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 4,
#   'grade': 6,
#   'sqft_above': 1280,
#   'sqft_basement': 0,
#   'yr_built': 1985,
#   'yr_renovated': 0,
#   'zipcode': 98002,
#   'sqft_living15': 1280,
#   'sqft_lot15': 4366},
#  {'bedrooms': 4,
#   'bathrooms': 2.25,
#   'sqft_living': 2550,
#   'sqft_lot': 7650,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 2,
#   'condition': 4,
#   'grade': 9,
#   'sqft_above': 2550,
#   'sqft_basement': 0,
#   'yr_built': 1996,
#   'yr_renovated': 0,
#   'zipcode': 98106,
#   'sqft_living15': 2550,
#   'sqft_lot15': 7650},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 1730,
#   'sqft_lot': 21183,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1030,
#   'sqft_basement': 700,
#   'yr_built': 1955,
#   'yr_renovated': 0,
#   'zipcode': 98168,
#   'sqft_living15': 1610,
#   'sqft_lot15': 13000},
#  {'bedrooms': 3,
#   'bathrooms': 1.0,
#   'sqft_living': 1120,
#   'sqft_lot': 7500,
#   'floors': 1.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1120,
#   'sqft_basement': 0,
#   'yr_built': 1965,
#   'yr_renovated': 0,
#   'zipcode': 98146,
#   'sqft_living15': 1120,
#   'sqft_lot15': 5000},
#  {'bedrooms': 3,
#   'bathrooms': 1.75,
#   'sqft_living': 1300,
#   'sqft_lot': 1237,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1060,
#   'sqft_basement': 240,
#   'yr_built': 2008,
#   'yr_renovated': 0,
#   'zipcode': 98027,
#   'sqft_living15': 1350,
#   'sqft_lot15': 942},
#  {'bedrooms': 4,
#   'bathrooms': 2.5,
#   'sqft_living': 1610,
#   'sqft_lot': 4568,
#   'floors': 2.0,
#   'waterfront': 0,
#   'view': 0,
#   'condition': 3,
#   'grade': 7,
#   'sqft_above': 1610,
#   'sqft_basement': 0,
#   'yr_built': 2006,
#   'yr_renovated': 0,
#   'zipcode': 98001,
#   'sqft_living15': 1834,
#   'sqft_lot15': 4604},
#  ...]

# %%
MultipleDataSchema(inputs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 MultipleDataSchema(inputs)
#
# TypeError: BaseModel.__init__() takes 1 positional argument but 2 were given

# %%
from src.predict import make_prediction
from src.pipeline import df_model

# %%
df = df_model(data)
df.head()
# Out:
#                id             date  bedrooms  bathrooms  floors waterfront  \
# 17384  1453602313  20141029T000000         2          1       3          0
# 722    2225059214  20140808T000000         4          3       2          0
# 2680   2768000270  20140625T000000         2          0       1          0
# 18754  6819100040  20140624T000000         2          1       1          0
# 14554  4027700666  20150426T000000         4          2       2          0
#
#       view condition  grade  yr_built  ...  zipcode_encoded view_encoded  \
# 17384    0         3      7      1999  ...              0.0          0.0
# 722      0         4  00000      1988  ...              1.0          0.0
# 2680     0         3      7      1914  ...              1.0          0.0
# 18754    0         4      8      1927  ...              1.0          0.0
# 14554    2         3      9      2002  ...              2.0          1.0
#
#        condition_encoded  grade_encoded  sqft_living  sqft_lot  sqft_above  \
# 17384                0.0            0.0     0.120045  0.000832    0.141711
# 722                  1.0            1.0     0.486976  0.043943    0.574866
# 2680                 0.0            0.0     0.121178  0.002593    0.110963
# 18754                1.0            2.0     0.086070  0.001683    0.101604
# 14554                0.0            3.0     0.318233  0.007664    0.375668
#
#        sqft_basement  sqft_living15  sqft_lot15
# 17384           0.00       0.137184    0.002062
# 722             0.00       0.642599    0.092183
# 2680            0.08       0.138989    0.008120
# 18754           0.00       0.182310    0.005605
# 14554           0.00       0.319495    0.033175
#
# [5 rows x 26 columns]

# %%
make_prediction()
# Out:
# INFO:root:Iniciado processo de aplicação do modelo
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 make_prediction()
#
# File c:\Users\Carolina\OneDrive\Github\mlops\src\predict.py:28, in make_prediction()
#      24 model_folder = os.path.join(os.path.dirname(config.ml_config.trained_model_file), '*')
#      25 models = sorted(
#      26     glob.iglob(model_folder), key=os.path.getctime, reverse=True)
# ---> 28 load_model = pickle.load(open(models[0], 'rb'))
#      29 logging.info(f"modelo {models[0]} carregado")
#      30 validated_data, errors = validate_inputs(raw_data=data, step = "pred")
#
# UnpicklingError: invalid load key, '*'.
